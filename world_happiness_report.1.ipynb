# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# # Checking Null values in the dataframe

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # Checking the datatypes of the columns.

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df['Happiness Score'].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
df.loc[df['Happiness Score']== " "]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df["Happiness Score"]=df["Happiness Score"].replace(" ",np.nan)

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # Making DataFrame for the Nominal Data

# %%
df_visualization_nominal=df[['Country','Region']].copy()

# %%
df_visualization_nominal.columns
# Out:
# Index(['Country', 'Region'], dtype='object')

# %% [markdown]
# # Visualization of the Data:

# %%
import seaborn as sns

# %%
ax = sns.countplot(x="Country", data=df_visualization_nominal)
print(df_visualization_nominal["Country"].value_counts())
# Out:
# Macedonia                  1
# Colombia                   1
# Senegal                    1
# Myanmar                    1
# Greece                     1
#                           ..
# Thailand                   1
# Malawi                     1
# Palestinian Territories    1
# Chad                       1
# Gabon                      1
# Name: Country, Length: 158, dtype: int64

# %%
ax = sns.countplot(x="Region", data=df_visualization_nominal)
print(df_visualization_nominal["Region"].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# # Checking the distribution of the continuous value of the float type columns

# %%
df_visualization_continous=df[["Happiness Rank","Happiness Score"]]

# %%
import seaborn as sns
sns.distplot(df_visualization_continous['Happiness Score'],kde=True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df_visualization_continous['Happiness Rank'],kde=True)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
df_visualization_continous=df[["Standard Error","Happiness Score"]]
sns.distplot(df_visualization_continous['Standard Error'],kde=True)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
df_visualization_continous=df[["Economy (GDP per Capita)","Happiness Score"]]
sns.distplot(df_visualization_continous['Economy (GDP per Capita)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
df_visualization_continous=df[["Family","Happiness Score"]]
sns.distplot(df_visualization_continous['Family'],kde=True)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
df_visualization_continous=df[["Health (Life Expectancy)","Happiness Score"]]
sns.distplot(df_visualization_continous['Health (Life Expectancy)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
df_visualization_continous=df[["Freedom","Happiness Score"]]
sns.distplot(df_visualization_continous['Freedom'],kde=True)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
df_visualization_continous=df[["Trust (Government Corruption)","Happiness Score"]]
sns.distplot(df_visualization_continous['Trust (Government Corruption)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
df_visualization_continous=df[["Generosity","Happiness Score"]]
sns.distplot(df_visualization_continous['Generosity'],kde=True)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
df_visualization_continous=df[["Dystopia Residual","Happiness Score"]]
sns.distplot(df_visualization_continous['Dystopia Residual'],kde=True)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# # Describe the dataset:

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation of the columns with the target columns:

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Outliers Check:

# %%
df.dtypes
# Out:
# Country                            int32
# Region                             int32
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df['Happiness Rank'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Happiness Score'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Standard Error'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Economy (GDP per Capita)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Family'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Health (Life Expectancy)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Freedom'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Trust (Government Corruption)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Generosity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Dystopia Residual'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Considering the outlier removal

# %%
from scipy.stats import zscore
import numpy as np

# %%
df.shape
# Out:
# (158, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 9

# %%
df_new=df[(z<3)]
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 0        135       9               1            7.587         0.03411
# 0        135       9               1            7.587         0.03411
# 0        135       9               1            7.587         0.03411
# 0        135       9               1            7.587         0.03411
# ..       ...     ...             ...              ...             ...
# 157      141       8             158            2.839         0.06727
# 157      141       8             158            2.839         0.06727
# 157      141       8             158            2.839         0.06727
# 157      141       8             158            2.839         0.06727
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df_new.shape
# Out:
# (1887, 12)

# %%
#percentage of loss data

# %%
df_new=df[(z<3).all(axis=1)]
print("Old Dataframe", df.shape)
print("New Dataframe",df_new.shape)
print("total_dropped_rows", df.shape[0]-df_new.shape[0])
# Out:
# Old Dataframe (158, 12)
# New Dataframe (149, 12)
# total_dropped_rows 9

# %%
loss_percent=(158-149)/158*100
loss_percent
# Out:
# 5.69620253164557

# %% [markdown]
# # Separating the columns into features and target:

# %%
features=df.drop("Happiness Score",axis=1)
target=df["Happiness Score"]

# %% [markdown]
# # Scaling the data using Min-Max Scaler:

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i}, the testing accuracy is:- {r2_score(target_train,pred_train)}")
    print(f"At random state {i}, the testing accuracy is:- {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, the testing accuracy is:- 0.9999999514441257
# At random state 0, the testing accuracy is:- 0.999999902494247
#
#
# At random state 1, the testing accuracy is:- 0.9999999444138908
# At random state 1, the testing accuracy is:- 0.9999999394454414
#
#
# At random state 2, the testing accuracy is:- 0.9999999405491521
# At random state 2, the testing accuracy is:- 0.9999999523828854
#
#
# At random state 3, the testing accuracy is:- 0.9999999420745156
# At random state 3, the testing accuracy is:- 0.9999999470792729
#
#
# At random state 4, the testing accuracy is:- 0.9999999379277369
# At random state 4, the testing accuracy is:- 0.9999999520348243
#
#
# At random state 5, the testing accuracy is:- 0.9999999487684214
# At random state 5, the testing accuracy is:- 0.9999999027545904
#
#
# At random state 6, the testing accuracy is:- 0.9999999463039511
# At random state 6, the testing accuracy is:- 0.9999999338566166
#
#
# ...

# %%
 features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.9999999439158268

# %% [markdown]
# Here we have handled the problem of the overfitting and the underfiting by checking the training and the testing score

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test,target_test, color='b')
plt.xlabel('Actual Score',fontsize=14)
plt.ylabel('Predicted Score',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %%
import pickle
filename = 'Score.pkl'
pickle.dump(lr, open(filename, 'wb'))
